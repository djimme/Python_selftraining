# %%
import numpy as np
np.random.seed(100)
a = np.random.standard_normal((9,4))
a
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
import pandas as pd

df = pd.DataFrame(a)
df
# Out:
#           0         1         2         3
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df.columns = ['No1', 'No2', 'No3', 'No4']
df
# Out:
#         No1       No2       No3       No4
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df['No2'].mean()
# Out:
# 0.701033094145646

# %%
dates = pd.date_range('2020-1-1', periods = 9, freq='M')
df.index = dates
print(dates)
df
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30'],
#               dtype='datetime64[ns]', freq='M')
#                  No1       No2       No3       No4
# 2020-01-31 -1.749765  0.342680  1.153036 -0.252436
# 2020-02-29  0.981321  0.514219  0.221180 -1.070043
# 2020-03-31 -0.189496  0.255001 -0.458027  0.435163
# 2020-04-30 -0.583595  0.816847  0.672721 -0.104411
# 2020-05-31 -0.531280  1.029733 -0.438136 -1.118318
# 2020-06-30  1.618982  1.541605 -0.251879 -0.842436
# 2020-07-31  0.184519  0.937082  0.731000  1.361556
# 2020-08-31 -0.326238  0.055676  0.222400 -1.443217
# 2020-09-30 -0.756352  0.816454  0.750445 -0.455947

# %%
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean  -0.150212  0.701033  0.289193 -0.387788
# std    0.988306  0.457685  0.579920  0.877532
# min   -1.749765  0.055676 -0.458027 -1.443217
# 25%   -0.583595  0.342680 -0.251879 -1.070043
# 50%   -0.326238  0.816454  0.222400 -0.455947
# 75%    0.184519  0.937082  0.731000 -0.104411
# max    1.618982  1.541605  1.153036  1.361556

# %%
df.sum()
# Out:
# No1   -1.351906
# No2    6.309298
# No3    2.602739
# No4   -3.490089
# dtype: float64

# %%
df.mean()
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2020-01-31   -0.126621
# 2020-02-29    0.161669
# 2020-03-31    0.010661
# 2020-04-30    0.200390
# 2020-05-31   -0.264500
# 2020-06-30    0.516568
# 2020-07-31    0.803539
# 2020-08-31   -0.372845
# 2020-09-30    0.088650
# Freq: M, dtype: float64

# %%
df.cumsum()
# Out:
#                  No1       No2       No3       No4
# 2020-01-31 -1.749765  0.342680  1.153036 -0.252436
# 2020-02-29 -0.768445  0.856899  1.374215 -1.322479
# 2020-03-31 -0.957941  1.111901  0.916188 -0.887316
# 2020-04-30 -1.541536  1.928748  1.588909 -0.991727
# 2020-05-31 -2.072816  2.958480  1.150774 -2.110045
# 2020-06-30 -0.453834  4.500086  0.898895 -2.952481
# 2020-07-31 -0.269316  5.437168  1.629895 -1.590925
# 2020-08-31 -0.595554  5.492844  1.852294 -3.034142
# 2020-09-30 -1.351906  6.309298  2.602739 -3.490089

# %%
np.sqrt(abs(df)).sum()
# Out:
# No1    7.384345
# No2    7.075190
# No3    6.397719
# No4    7.538440
# dtype: float64

# %%
100*df+20
# Out:
#                    No1         No2         No3         No4
# 2020-01-31 -154.976547   54.268040  135.303580   -5.243604
# 2020-02-29  118.132079   71.421884   42.117967  -87.004333
# 2020-03-31    1.050417   45.500144  -25.802699   63.516349
# 2020-04-30  -38.359505  101.684707   87.272081    9.558886
# 2020-05-31  -33.128038  122.973269  -23.813562  -91.831825
# 2020-06-30  181.898166  174.160517   -5.187914  -64.243574
# 2020-07-31   38.451869  113.708220   93.100034  156.155613
# 2020-08-31  -12.623806   25.567601   42.239961 -124.321700
# 2020-09-30  -55.635231  101.645401   95.044476  -25.594693

# %%
from pylab import plt, mpl
plt.style.use('seaborn')
mpl.rcParams['font.family']='serif'
# %matplotlib inline

df.cumsum().plot(lw=2, figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
#df.plot.bar(figsize=(10,6), rot=15);
df.plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df['Quarter'] = ['Q1', 'Q1', 'Q1', 'Q2', 'Q2', 'Q2', 'Q3', 'Q3', 'Q3']
df.aggregate([sum], axis=0)
# Out:
#           No1       No2       No3       No4             Quarter
# sum -1.351906  6.309298  2.602739 -3.490089  Q1Q1Q1Q2Q2Q2Q3Q3Q3

# %%
groups = df.groupby('Quarter')
groups.aggregate([min, max]).round(2)
# Out:
#           No1         No2         No3         No4
#           min   max   min   max   min   max   min   max
# Quarter
# Q1      -1.75  0.98  0.26  0.51 -0.46  1.15 -1.07  0.44
# Q2      -0.58  1.62  0.82  1.54 -0.44  0.67 -1.12 -0.10
# Q3      -0.76  0.18  0.06  0.94  0.22  0.75 -1.44  1.36

# %%
df['Odd_Even'] = ['Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even', 'Odd' ]
df
# Out:
#                  No1       No2       No3       No4 Quarter Odd_Even
# 2020-01-31 -1.749765  0.342680  1.153036 -0.252436      Q1      Odd
# 2020-02-29  0.981321  0.514219  0.221180 -1.070043      Q1     Even
# 2020-03-31 -0.189496  0.255001 -0.458027  0.435163      Q1      Odd
# 2020-04-30 -0.583595  0.816847  0.672721 -0.104411      Q2     Even
# 2020-05-31 -0.531280  1.029733 -0.438136 -1.118318      Q2      Odd
# 2020-06-30  1.618982  1.541605 -0.251879 -0.842436      Q2     Even
# 2020-07-31  0.184519  0.937082  0.731000  1.361556      Q3      Odd
# 2020-08-31 -0.326238  0.055676  0.222400 -1.443217      Q3     Even
# 2020-09-30 -0.756352  0.816454  0.750445 -0.455947      Q3      Odd

# %%
groups = df.groupby(['Quarter', 'Odd_Even'])
groups.size()
# Out:
# Quarter  Odd_Even
# Q1       Even        1
#          Odd         2
# Q2       Even        2
#          Odd         1
# Q3       Even        1
#          Odd         2
# dtype: int64
