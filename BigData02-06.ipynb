# %%
import pandas as pd

# %%
df_hr1 = pd.DataFrame({'이름':['장화','홍련'], '부서':['영업','회계'], '직급':['팀장','사원']})
df_hr1
# Out:
#    이름  부서  직급
# 0  장화  영업  팀장
# 1  홍련  회계  사원

# %%
df_hr2 = pd.DataFrame({'이름':['콩쥐','팥쥐'], '직급':['사원', '팀장'], '부서':['영업','인사']})
df_hr2
# Out:
#    이름  직급  부서
# 0  콩쥐  사원  영업
# 1  팥쥐  팀장  인사

# %%
pd.concat([df_hr1, df_hr2], axis=0)
# Out:
#    이름  부서  직급
# 0  장화  영업  팀장
# 1  홍련  회계  사원
# 0  콩쥐  영업  사원
# 1  팥쥐  인사  팀장

# %%
pd.concat([df_hr1, df_hr2], axis=0, ignore_index=True)
# Out:
#    이름  부서  직급
# 0  장화  영업  팀장
# 1  홍련  회계  사원
# 2  콩쥐  영업  사원
# 3  팥쥐  인사  팀장

# %%
df_hr3=pd.DataFrame({'이름':['콩쥐','팥쥐'], '부서':['영업','인사'], '급여':[3500, 2800]})
pd.concat([df_hr1,df_hr3], axis=0, ignore_index=True)
# Out:
#    이름  부서   직급      급여
# 0  장화  영업   팀장     NaN
# 1  홍련  회계   사원     NaN
# 2  콩쥐  영업  NaN  3500.0
# 3  팥쥐  인사  NaN  2800.0

# %%
df_hr4=pd.Series({1:2500}, name='급여')
pd.concat([df_hr1, df_hr4], axis=1)
# Out:
#    이름  부서  직급      급여
# 0  장화  영업  팀장     NaN
# 1  홍련  회계  사원  2500.0

# %%
df_hr5=pd.DataFrame({'급여':[4500,3000,3500]})

# %%
pd.concat([df_hr1, df_hr5], axis=1)
# Out:
#     이름   부서   직급    급여
# 0   장화   영업   팀장  4500
# 1   홍련   회계   사원  3000
# 2  NaN  NaN  NaN  3500

# %%
product = pd.DataFrame({'상품코드':['G1','G2','G3','G4'], '상품명':['우유','감자','빵','치킨']})
sale = pd.DataFrame({'주문번호':[1001,1002,1002,1003,1004], '상품코드':['G4','G3','G1','G3','G5'], '주문수량':[1,4,2,2,3]})
sale.merge(product,on='상품코드',how='inner')
# Out:
#    주문번호 상품코드  주문수량 상품명
# 0  1001   G4     1  치킨
# 1  1002   G3     4   빵
# 2  1003   G3     2   빵
# 3  1002   G1     2  우유

# %%
sale.merge(product, on='상품코드',how='outer', sort=True)
# Out:
#      주문번호 상품코드  주문수량  상품명
# 0  1002.0   G1   2.0   우유
# 1     NaN   G2   NaN   감자
# 2  1002.0   G3   4.0    빵
# 3  1003.0   G3   2.0    빵
# 4  1001.0   G4   1.0   치킨
# 5  1004.0   G5   3.0  NaN

# %%
sale.merge(product,left_on='상품코드',right_on='상품코드', how='left')
# Out:
#    주문번호 상품코드  주문수량  상품명
# 0  1001   G4     1   치킨
# 1  1002   G3     4    빵
# 2  1002   G1     2   우유
# 3  1003   G3     2    빵
# 4  1004   G5     3  NaN
