# %% [markdown]
# ## 2장 4절 조건에 맞는 데이터 탐색 및 수정

# %%
import pandas as pd

# %%
students = pd.DataFrame({'이름':['장화','홍련','콩쥐','팥쥐','해님','달님'], '국어':[70,85,None,100,None,85], \
                         '수학':[65,100,80,95,None,70]})
students
# Out:
#    이름     국어     수학
# 0  장화   70.0   65.0
# 1  홍련   85.0  100.0
# 2  콩쥐    NaN   80.0
# 3  팥쥐  100.0   95.0
# 4  해님    NaN    NaN
# 5  달님   85.0   70.0

# %%
students[students['이름']=='장화']
# Out:
#    이름    국어    수학
# 0  장화  70.0  65.0

# %%
students[(students['국어']>=80)&(students['수학']>=80)]
# Out:
#    이름     국어     수학
# 1  홍련   85.0  100.0
# 3  팥쥐  100.0   95.0

# %%
students.loc[6, '이름':'수학']=['별님',50,60]
students
# Out:
#    이름     국어     수학
# 0  장화   70.0   65.0
# 1  홍련   85.0  100.0
# 2  콩쥐    NaN   80.0
# 3  팥쥐  100.0   95.0
# 4  해님    NaN    NaN
# 5  달님   85.0   70.0
# 6  별님   50.0   60.0

# %%
students.loc[(students['국어']>=80)&(students['수학']>=70), '합격'] = 'Pass'
students
# Out:
#    이름     국어     수학    합격
# 0  장화   70.0   65.0   NaN
# 1  홍련   85.0  100.0  Pass
# 2  콩쥐    NaN   80.0   NaN
# 3  팥쥐  100.0   95.0  Pass
# 4  해님    NaN    NaN   NaN
# 5  달님   85.0   70.0  Pass
# 6  별님   50.0   60.0   NaN

# %%
students.loc[students['합격']!='Pass', '합격']='Fail'
students
# Out:
#    이름     국어     수학    합격
# 0  장화   70.0   65.0  Fail
# 1  홍련   85.0  100.0  Pass
# 2  콩쥐    NaN   80.0  Fail
# 3  팥쥐  100.0   95.0  Pass
# 4  해님    NaN    NaN  Fail
# 5  달님   85.0   70.0  Pass
# 6  별님   50.0   60.0  Fail

# %%
import numpy as np

# %%
condition_list = [(students['국어']>=90), (students['국어'] >= 80)&(students['국어']<90), \
                 (students['국어']>=70)&(students['국어']<80)]
choice_list = ['A','B','C']
students['점수'] = np.select(condition_list, choice_list,default='F')
students
# Out:
#    이름     국어     수학    합격 점수
# 0  장화   70.0   65.0  Fail  C
# 1  홍련   85.0  100.0  Pass  B
# 2  콩쥐    NaN   80.0  Fail  F
# 3  팥쥐  100.0   95.0  Pass  A
# 4  해님    NaN    NaN  Fail  F
# 5  달님   85.0   70.0  Pass  B
# 6  별님   50.0   60.0  Fail  F

# %%
students.isna()
# Out:
#       이름     국어     수학     합격     점수
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False  False
# 3  False  False  False  False  False
# 4  False   True   True  False  False
# 5  False  False  False  False  False
# 6  False  False  False  False  False

# %%
students.notna()
# Out:
#      이름     국어     수학    합격    점수
# 0  True   True   True  True  True
# 1  True   True   True  True  True
# 2  True  False   True  True  True
# 3  True   True   True  True  True
# 4  True  False  False  True  True
# 5  True   True   True  True  True
# 6  True   True   True  True  True

# %%
students.isna().sum()
# Out:
# 이름    0
# 국어    2
# 수학    1
# 합격    0
# 점수    0
# dtype: int64

# %%
students.isna().sum(1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    2
# 5    0
# 6    0
# dtype: int64

# %%
df_stu = students.copy()
df_stu
# Out:
#    이름     국어     수학    합격 점수
# 0  장화   70.0   65.0  Fail  C
# 1  홍련   85.0  100.0  Pass  B
# 2  콩쥐    NaN   80.0  Fail  F
# 3  팥쥐  100.0   95.0  Pass  A
# 4  해님    NaN    NaN  Fail  F
# 5  달님   85.0   70.0  Pass  B
# 6  별님   50.0   60.0  Fail  F

# %%
df_stu.dropna()
# Out:
#    이름     국어     수학    합격 점수
# 0  장화   70.0   65.0  Fail  C
# 1  홍련   85.0  100.0  Pass  B
# 3  팥쥐  100.0   95.0  Pass  A
# 5  달님   85.0   70.0  Pass  B
# 6  별님   50.0   60.0  Fail  F

# %%
df_stu=students.copy()
df_stu
# Out:
#    이름     국어     수학    합격 점수
# 0  장화   70.0   65.0  Fail  C
# 1  홍련   85.0  100.0  Pass  B
# 2  콩쥐    NaN   80.0  Fail  F
# 3  팥쥐  100.0   95.0  Pass  A
# 4  해님    NaN    NaN  Fail  F
# 5  달님   85.0   70.0  Pass  B
# 6  별님   50.0   60.0  Fail  F

# %%
df_stu.dropna(thresh=4)
# Out:
#    이름     국어     수학    합격 점수
# 0  장화   70.0   65.0  Fail  C
# 1  홍련   85.0  100.0  Pass  B
# 2  콩쥐    NaN   80.0  Fail  F
# 3  팥쥐  100.0   95.0  Pass  A
# 5  달님   85.0   70.0  Pass  B
# 6  별님   50.0   60.0  Fail  F

# %%
df_health = pd.DataFrame(data = {'연도':[2017,2018,2019,2020,2021,2022], \
                                 '키':[160,162,165,None,None,166], \
                                 '몸무게':[53,52,None,50,51,54],\
                                 '시력':[1.2, None, 1.2, 1.2, 1.1, 0.8], \
                                 '병결':[None, None, None, 2, None, 1]})
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  NaN
# 1  2018  162.0  52.0  NaN  NaN
# 2  2019  165.0   NaN  1.2  NaN
# 3  2020    NaN  50.0  1.2  2.0
# 4  2021    NaN  51.0  1.1  NaN
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health.fillna(0)
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  0.0
# 1  2018  162.0  52.0  0.0  0.0
# 2  2019  165.0   0.0  1.2  0.0
# 3  2020    0.0  50.0  1.2  2.0
# 4  2021    0.0  51.0  1.1  0.0
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  NaN
# 1  2018  162.0  52.0  NaN  NaN
# 2  2019  165.0   NaN  1.2  NaN
# 3  2020    NaN  50.0  1.2  2.0
# 4  2021    NaN  51.0  1.1  NaN
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health.fillna(df_health.mean())
# Out:
#      연도       키   몸무게   시력   병결
# 0  2017  160.00  53.0  1.2  1.5
# 1  2018  162.00  52.0  1.1  1.5
# 2  2019  165.00  52.0  1.2  1.5
# 3  2020  163.25  50.0  1.2  2.0
# 4  2021  163.25  51.0  1.1  1.5
# 5  2022  166.00  54.0  0.8  1.0

# %%
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  NaN
# 1  2018  162.0  52.0  NaN  NaN
# 2  2019  165.0   NaN  1.2  NaN
# 3  2020    NaN  50.0  1.2  2.0
# 4  2021    NaN  51.0  1.1  NaN
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health['병결'] = df_health['병결'].fillna(0)
df_health['몸무게'] = df_health['몸무게'].fillna(df_health['몸무게'].mean())

# %%
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  0.0
# 1  2018  162.0  52.0  NaN  0.0
# 2  2019  165.0  52.0  1.2  0.0
# 3  2020    NaN  50.0  1.2  2.0
# 4  2021    NaN  51.0  1.1  0.0
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health.fillna(method='pad', inplace=True)
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  0.0
# 1  2018  162.0  52.0  1.2  0.0
# 2  2019  165.0  52.0  1.2  0.0
# 3  2020  165.0  50.0  1.2  2.0
# 4  2021  165.0  51.0  1.1  0.0
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health['키'].drop_duplicates()
# Out:
# 0    160.0
# 1    162.0
# 2    165.0
# 5    166.0
# Name: 키, dtype: float64

# %%
set(df_health['키'])
# Out:
# {160.0, 162.0, 165.0, 166.0}

# %%
df_health
# Out:
#      연도      키   몸무게   시력   병결
# 0  2017  160.0  53.0  1.2  0.0
# 1  2018  162.0  52.0  1.2  0.0
# 2  2019  165.0  52.0  1.2  0.0
# 3  2020  165.0  50.0  1.2  2.0
# 4  2021  165.0  51.0  1.1  0.0
# 5  2022  166.0  54.0  0.8  1.0

# %%
df_health[['시력','병결']].drop_duplicates()
# Out:
#     시력   병결
# 0  1.2  0.0
# 3  1.2  2.0
# 4  1.1  0.0
# 5  0.8  1.0
