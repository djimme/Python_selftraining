# %%
import pandas as pd

df1 = pd.DataFrame(['100', '200', '300', '400'], index=['a','b', 'c', 'd'], columns = ['A', ])
df1
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df2 = pd.DataFrame(['200', '150', '50'], index=['f', 'b', 'd'], columns = ['B', ])
df2
# Out:
#      B
# f  200
# b  150
# d   50

# %% [markdown]
# ### Concatenation

# %%
df1.append(df2, sort=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_26136\50354407.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, sort=False)
#      A    B
# a  100  NaN
# b  200  NaN
# c  300  NaN
# d  400  NaN
# f  NaN  200
# b  NaN  150
# d  NaN   50

# %%
df1.append(df2, ignore_index=True, sort=False)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_26136\2226406127.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2, ignore_index=True, sort=False)
#      A    B
# 0  100  NaN
# 1  200  NaN
# 2  300  NaN
# 3  400  NaN
# 4  NaN  200
# 5  NaN  150
# 6  NaN   50

# %%
pd.concat((df1, df2), sort=False)
# Out:
#      A    B
# a  100  NaN
# b  200  NaN
# c  300  NaN
# d  400  NaN
# f  NaN  200
# b  NaN  150
# d  NaN   50

# %%
pd.concat((df1, df2), ignore_index=True, sort=False)
# Out:
#      A    B
# 0  100  NaN
# 1  200  NaN
# 2  300  NaN
# 3  400  NaN
# 4  NaN  200
# 5  NaN  150
# 6  NaN   50

# %% [markdown]
# ### Joining

# %%
df1.join(df2)
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df2.join(df1)
# Out:
#      B    A
# f  200  NaN
# b  150  200
# d   50  400

# %%
df1.join(df2, how = 'left')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df1.join(df2, how='right')
# Out:
#      A    B
# f  NaN  200
# b  200  150
# d  400   50

# %%
df1.join(df2, how='inner')
# Out:
#      A    B
# b  200  150
# d  400   50

# %%
df1.join(df2, how='outer')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200

# %%
df = pd.DataFrame()
df['A'] = df1
df
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df['B'] = df2
df
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df = pd.DataFrame({'A':df1['A'], 'B':df2['B']})
df
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200
